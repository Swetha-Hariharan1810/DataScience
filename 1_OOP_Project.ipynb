# %%
# !pip install nlpcloud
# Out:
# Collecting nlpcloud
#   Downloading nlpcloud-1.0.42-py3-none-any.whl (4.5 kB)
# Requirement already satisfied: requests in /home/swetha/anaconda3/lib/python3.10/site-packages (from nlpcloud) (2.28.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/swetha/anaconda3/lib/python3.10/site-packages (from requests->nlpcloud) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/swetha/anaconda3/lib/python3.10/site-packages (from requests->nlpcloud) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/swetha/anaconda3/lib/python3.10/site-packages (from requests->nlpcloud) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /home/swetha/anaconda3/lib/python3.10/site-packages (from requests->nlpcloud) (3.4)
# Installing collected packages: nlpcloud
# Successfully installed nlpcloud-1.0.42

# %%
import nlpcloud
class NLPApp:
    
    def __init__(self):
        self.__database = {}
        self.__first_menu()
        
    def __first_menu(self):
        first_input = first_input = input("""
        Hi! how would you like to proceed?
        1. Not a member? Register
        2. Already a member? Login
        3. Galti se aa gaye? Exit
        """)
        
        if first_input == "1":
            self.__register()
        elif first_input == "2":
            self.__login()
        else:
            exit()
            
    def __second_menu(self):
        second_input = first_input = input("""
        Hi! how would you like to proceed?
        1. NER
        2. Language Detection
        3. Sentiment Analysis
        4. Logout
        """)
        
        if second_input == "1":
            self.__ner()
        elif second_input == "2":
            self.__language_detection()
        elif second_input == "2":
            self.__sentiment_analysis()
        else:
            exit()
    
    
        
    def __register(self):
        name = input("enter name:")
        email = input("enter email:")
        password = input("enter password:")
        
        if email in self.__database:
            print("email already exists")
        else:
            self.__database[email] = [name,password]
            print("registration successful. Now login")
            print(self.__database)
            self.__first_menu()
    
    def __login(self):
        email = input("enter email")
        password = input("enter password")
        
        if email in self.__database:
            if self.__database[email][1] == password:
                print("login successful")
                self.__second_menu()
            else:
                print("wrong password.Try again")
                self.__login()
        else:
            print("This email is not registered")
            self.__first_menu()
            
    def __ner(self):
        para = input("enter the paragraph")
        search_term = input("enter the word you want to search")


        client = nlpcloud.Client("finetuned-gpt-neox-20b", "2b58d7fb9af09e617ee525e78c7766b6d8c5bb61", gpu=True, lang="en")
        response = client.entities(para, searched_entity= search_term)
        
        print(response)
        self.__second_menu()
        
    def __sentiment_analysis(self):
        para = input("enter the paragraph")
        #search_term = input("enter the word you want to search")


        client = nlpcloud.Client("finetuned-gpt-neox-20b", "2b58d7fb9af09e617ee525e78c7766b6d8c5bb61", gpu=True, lang="en")
        response = client.sentiment(para)
        
        L = []
        for i in response["scored_labels"]:
            L.append(i['score'])
        
        index = sorted(list(enumerate(L)), key=lamda x:x[1],reverse = True)[0][0]
        
        print(response['scored_labels'][index]['labels'])
        self.__second_menu()
        
        
    
obj = NLPApp()
# Out:
#         Hi! how would you like to proceed?
#         1. Not a member? Register
#         2. Already a member? Login
#         3. Galti se aa gaye? Exit
#         2
# enter emailswethah@IISc.ac.in
# enter password123
# This email is not registered
#
#         Hi! how would you like to proceed?
#         1. Not a member? Register
#         2. Already a member? Login
#         3. Galti se aa gaye? Exit
#         2
# enter emailvihanas@IISc.ac.in
# enter password456
# This email is not registered
#
#         Hi! how would you like to proceed?
#         1. Not a member? Register
#         2. Already a member? Login
#         3. Galti se aa gaye? Exit
#         1
# enter name:swetha
# enter email:swetha@gmail.com
# enter password:123
# registration successful. Now login
# {'swetha@gmail.com': ['swetha', '123']}
#
#         Hi! how would you like to proceed?
#         1. Not a member? Register
#         2. Already a member? Login
#         3. Galti se aa gaye? Exit
#         2
# enter emailswetha@gmail.com
# enter password123
# login successful
#
#         Hi! how would you like to proceed?
#         1. NER
#         2. Language Detection
#         3. Sentiment Analysis
#         4. Logout
#         1
# enter the paragraphcan i learn python? as i am finding java difficult
# enter the word you want to searchprogramming languages
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/nlpcloud/__init__.py:180, in Client.entities(self, text, searched_entity)
#     179 try:
# --> 180     r.raise_for_status()
#     181 except HTTPError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://api.nlpcloud.io/v1/gpu/finetuned-gpt-neox-20b/entities
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# Cell In[1], line 83
#      77         response = client.entities(para, searched_entity= search_term)
#      79         print(response)
# ---> 83 obj = NLPApp()
#
# Cell In[1], line 6, in NLPApp.__init__(self)
#       4 def __init__(self):
#       5     self.__database = {}
# ----> 6     self.__first_menu()
#
# Cell In[1], line 19, in NLPApp.__first_menu(self)
#      17     self.__register()
#      18 elif first_input == "2":
# ---> 19     self.__login()
#      20 else:
#      21     exit()
#
# Cell In[1], line 69, in NLPApp.__login(self)
#      67 else:
#      68     print("This email is not registered")
# ---> 69     self.__first_menu()
#
# Cell In[1], line 19, in NLPApp.__first_menu(self)
#      17     self.__register()
#      18 elif first_input == "2":
# ---> 19     self.__login()
#      20 else:
#      21     exit()
#
# Cell In[1], line 69, in NLPApp.__login(self)
#      67 else:
#      68     print("This email is not registered")
# ---> 69     self.__first_menu()
#
# Cell In[1], line 17, in NLPApp.__first_menu(self)
#       9 first_input = first_input = input("""
#      10 Hi! how would you like to proceed?
#      11 1. Not a member? Register
#      12 2. Already a member? Login
#      13 3. Galti se aa gaye? Exit
#      14 """)
#      16 if first_input == "1":
# ---> 17     self.__register()
#      18 elif first_input == "2":
#      19     self.__login()
#
# Cell In[1], line 54, in NLPApp.__register(self)
#      52 print("registration successful. Now login")
#      53 print(self.__database)
# ---> 54 self.__first_menu()
#
# Cell In[1], line 19, in NLPApp.__first_menu(self)
#      17     self.__register()
#      18 elif first_input == "2":
# ---> 19     self.__login()
#      20 else:
#      21     exit()
#
# Cell In[1], line 63, in NLPApp.__login(self)
#      61 if self.__database[email][1] == password:
#      62     print("login successful")
# ---> 63     self.__second_menu()
#      64 else:
#      65     print("wrong password.Try again")
#
# Cell In[1], line 33, in NLPApp.__second_menu(self)
#      24 second_input = first_input = input("""
#      25 Hi! how would you like to proceed?
#      26 1. NER
#    (...)
#      29 4. Logout
#      30 """)
#      32 if second_input == "1":
# ---> 33     self.__ner()
#      34 elif second_input == "2":
#      35     self.__language_detection()
#
# Cell In[1], line 77, in NLPApp.__ner(self)
#      73 search_term = input("enter the word you want to search")
#      76 client = nlpcloud.Client("finetuned-gpt-neox-20b", "2b58d7fb9af09e617ee525e78c7766b6d8c5bb61", gpu=True, lang="en")
# ---> 77 response = client.entities(para, searched_entity= search_term)
#      79 print(response)
#
# File ~/anaconda3/lib/python3.10/site-packages/nlpcloud/__init__.py:185, in Client.entities(self, text, searched_entity)
#     182     if "<!DOCTYPE html>" in r.text:
#     183         raise HTTPError(str(err))
# --> 185     raise HTTPError(str(err) + ": " + str(r.text))
#     187 return r.json()
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://api.nlpcloud.io/v1/gpu/finetuned-gpt-neox-20b/entities: Rate limit: maximum number of requests per hour reached. Please contact support to learn how to increase this limit (if you are on the free plan, we encourage you to subscribe to the pay-as-you-go plan which provides a much higher throughput and many free requests).
